# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
customer_data = pd.read_csv('../Mall_Customers.csv')

# %%
customer_data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Form the feature matrix (X)
X = customer_data.iloc[:, 3:].values

# %%
# split in train and test set
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size=0.2, random_state=0)

# %%
# draw the dendagram
from scipy.cluster import hierarchy
dendagram = hierarchy.dendrogram(hierarchy.linkage(X, method='ward'))
plt.title('DENDROGRAM')
plt.xlabel('Customer')
plt.ylabel('Euclidean Distance')
# Out:
# Text(0, 0.5, 'Euclidean Distance')

# %% [raw]
# Optimal number of clusters is 5

# %%
# train the hiearchericall clustering model
from sklearn.cluster import AgglomerativeClustering
hcCluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
y_predX = hcCluster.fit_predict(X)
# Out:
# C:\Users\emax4\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
plt.scatter(X[y_predX == 0, 0], X[y_predX == 0, 1], c = 'blue', label = 'Cluster 1')
plt.scatter(X[y_predX == 1, 0], X[y_predX == 1, 1], c = 'red', label = 'Cluster 2')
plt.scatter(X[y_predX == 2, 0], X[y_predX == 2, 1], c = 'green', label = 'Cluster 3')
plt.scatter(X[y_predX == 3, 0], X[y_predX == 3, 1], c = 'yellow', label = 'Cluster 4')
plt.scatter(X[y_predX == 4, 0], X[y_predX == 4, 1], c = 'black', label = 'Cluster 5')
#plt.scatter(ksCluster.cluster_centers_[:, 0], hcCluster.cluster_centers_[:, 1],s = 300, c='magenta', label = 'centroids')

plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [raw]
# Based on the model, I recommend
# We could come up with programs, ensure continuous spending for cluster 2 (High income Earner who are Regular Spenders in our customer base)
# We could come up with marketing program or new products to target Cluster 5(High income Earner who are low Spenders) and Cluster 1 (Moderate income Earner who are moderate Spenders
# We simply ignore or offer low_cost products for cluster 4 (Low earners, and Low spenders(patronage) of our business)
